# %% [markdown]
# # Etapa 5 - Dataframes em Python
#
# <p>Neste Notebook se encontra todas as tabelas do banco de dados referente ao projeto RVV convertidas em dataframes Python, bem como as consultas (queries) presentes na especificação de requisitos funcionais.</p>
#
# <p>Iremos utilizar os recursos da biblioteca pandas para manipulação e criação dos dataframes, e as bibliotecas pyodbc e sqlalchemy para conexão ao SQL Server, SGBD onde foi implantado o projeto físico.</p>

# %% [markdown]
# ### Importa bibliotecas

# %%
import pyodbc
import pandas as pd
from sqlalchemy import create_engine, Column, Integer, String, Date, Numeric, Float, Boolean
from sqlalchemy.orm import sessionmaker
from sqlalchemy.ext.declarative import declarative_base

# %% [markdown]
# ### Conexão banco de dados SQL

# %%
server = 'localhost\SQLEXPRESS'
database = 'rvv'
username = ''
password = ''
conectDB = create_engine(
    f'mssql+pyodbc://{username}:{password}@{server}/{database}?driver=ODBC+Driver+17+for+SQL+Server')

# %% [markdown]
# ### Converte tabelas do sql em DataFrame do Python

# %% [markdown]
# #### _Departamentos_

# %%
df_Departamento = pd.read_sql_query("SELECT * FROM rvv.dbo.Departamento", conectDB)
df_Departamento
# Out:
#    Codigo_do_Departamento     Nome_do_Departamento  Status_do_Departamento
# 0                    1000      Diretoria Comercial                    True
# 1                    1001       Gerencia Comercial                    True
# 2                    1002              Regional SP                    True
# 3                    1003              Regional MG                    True
# 4                    1004              Regional RJ                    True
# 5                    1005  Administração Comercial                    True

# %% [markdown]
# #### _Cargos_

# %%
df_Cargo = pd.read_sql_query("SELECT * FROM rvv.dbo.Cargo", conectDB)
df_Cargo
# Out:
#    Codigo_do_Cargo            Nome_do_Cargo  Status_do_Cargo  \
# 0             1000        Diretor Comercial             True
# 1             1001        Gerente Comercial             True
# 2             1002     Supervisor Comercial             True
# 3             1003       Vendedor Comercial             True
# 4             1004  Analista Administrativo             True
#
#    nivel_hierarquia Base_de_Calculo
# 0                 1         Salario
# 1                 2         Salario
# 2                 3         Salario
# 3                 4     Faturamento
# 4                 4    Nao Elegivel

# %% [markdown]
# #### _Colaboradores_

# %%
df_Colaborador = pd.read_sql_query("SELECT * FROM rvv.dbo.Colaborador", conectDB)
df_Colaborador.head(8)
# Out:
#    Matricula_do_Colaborador    Nome_do_Colaborador Sexo             CPF  \
# 0                   1000001   Fernando Albuquerque    M  123.456.789-10
# 1                   1000002      Roberto Tamburelo    M  234.567.890-12
# 2                   1000003            Ana Walters    F  345.678.901-23
# 3                   1000004   Michael Sousa Santos    M  678.901.987-65
# 4                   1000005          Erick Alencar    M  456.789.012-34
# 5                   1000006        Stefany Moreira    F  567.890.123-45
# 6                   1000007  Maria Luiza Fernandes    F  309.851.267-95
# 7                   1000008          Murilo da Paz    M  321.705.694-99
#
#   Data_Nascimento  Codigo_do_Departamento  Codigo_do_Cargo   Salario  \
# 0      1971-05-06                    1000             1000  26550.32
# 1      1983-08-05                    1001             1001  18530.65
# 2      1990-12-01                    1002             1002  18530.65
# 3      1988-09-22                    1003             1002  18530.65
# 4      1988-06-05                    1004             1002  18530.65
# 5      1995-03-25                    1005             1004   6000.00
# 6      2001-01-19                    1002             1003   4000.00
# 7      1985-05-15                    1002             1003   4000.00
#
#    Status_do_Colaborador
# 0                   True
# 1                   True
# 2                   True
# 3                   True
# 4                   True
# 5                   True
# 6                   True
# 7                   True

# %% [markdown]
# #### _Indicadores_

# %%
df_Indicadores = pd.read_sql_query("SELECT * FROM rvv.dbo.Indicadores", conectDB)
df_Indicadores.head(8)
# Out:
#    Codigo_do_Indicador    Nome_do_Indicador  Codigo_do_Departamento  \
# 0                    1          Faturamento                    1002
# 1                    2  Qtde Itens Vendidos                    1002
# 2                    3     Itens por Pedido                    1002
# 3                    4            Devolucao                    1002
# 4                    5          Faturamento                    1002
# 5                    6  Qtde Itens Vendidos                    1002
# 6                    7     Itens por Pedido                    1002
# 7                    8            Devolucao                    1002
#
#    Codigo_do_Cargo  Peso_do_Indicador Inicio_Vigencia Final_Vigencia
# 0             1002               0.40      2023-01-01           None
# 1             1002               0.25      2023-01-01           None
# 2             1002               0.25      2023-01-01           None
# 3             1002               0.10      2023-01-01           None
# 4             1003               0.60      2023-01-01           None
# 5             1003               0.20      2023-01-01           None
# 6             1003               0.10      2023-01-01           None
# 7             1003               0.10      2023-01-01           None

# %% [markdown]
# #### _Metas_

# %%
df_Meta = pd.read_sql_query("SELECT * FROM rvv.dbo.Meta", conectDB)
df_Meta.head(8)
# Out:
#    id_meta  Matricula_do_Colaborador  Codigo_do_Indicador Inicio_Vigencia  \
# 0        1                   1000007                    5      2023-01-01
# 1        2                   1000008                    5      2023-01-01
# 2        3                   1000009                    5      2023-01-01
# 3        4                   1000010                    5      2023-01-01
# 4        5                   1000011                    5      2023-01-01
# 5        6                   1000007                    6      2023-01-01
# 6        7                   1000008                    6      2023-01-01
# 7        8                   1000009                    6      2023-01-01
#
#   Final_Vigencia  Valor_da_Meta
# 0           None        80000.0
# 1           None        78800.0
# 2           None        65320.0
# 3           None        90000.0
# 4           None        76350.0
# 5           None           20.0
# 6           None           26.0
# 7           None           23.0

# %% [markdown]
# #### _Resultados_

# %%
df_Resultado = pd.read_sql_query("SELECT * FROM rvv.dbo.Resultado", conectDB)
df_Resultado.head(8)
# Out:
#    id_resultado  Matricula_do_Colaborador  Codigo_do_Indicador Competencia  \
# 0             1                   1000007                    5  2023-01-01
# 1             2                   1000008                    5  2023-01-01
# 2             3                   1000009                    5  2023-01-01
# 3             4                   1000010                    5  2023-01-01
# 4             5                   1000011                    5  2023-01-01
# 5             6                   1000007                    6  2023-01-01
# 6             7                   1000008                    6  2023-01-01
# 7             8                   1000009                    6  2023-01-01
#
#    Valor_do_Resultado
# 0            49600.00
# 1            65404.00
# 2            47683.60
# 3            72900.00
# 4            45810.00
# 5                2.40
# 6                2.34
# 7                9.66

# %% [markdown]
# #### _Comissão_

# %%
df_Comissao = pd.read_sql_query("SELECT * FROM rvv.dbo.Comissao", conectDB)
df_Comissao.head(8)
# Out:
#    id_comissao  id_meta  id_resultado  Matricula_do_Colaborador  \
# 0            1        1             1                   1000007
# 1            2        6             6                   1000007
# 2            3       11            11                   1000007
# 3            4       16            16                   1000007
# 4            5        2             2                   1000008
# 5            6        7             7                   1000008
# 6            7       12            12                   1000008
# 7            8       17            17                   1000008
#
#    Codigo_do_Indicador Competencia  Valor_do_Resultado  Valor_da_Meta  \
# 0                    5  2023-01-01            49600.00        80000.0
# 1                    6  2023-01-01                2.40           20.0
# 2                    7  2023-01-01                0.36            2.0
# 3                    8  2023-01-01             2328.00         2400.0
# 4                    5  2023-01-01            65404.00        78800.0
# 5                    6  2023-01-01                2.34           26.0
# 6                    7  2023-01-01                0.48            2.0
# 7                    8  2023-01-01             1678.44         2364.0
#
#    Atingimento  Peso_do_Indicador  Base_Calculo   Comissao
# 0         0.62                0.6       14880.0  5535.3600
# 1         0.12                0.2       14880.0   357.1200
# 2         0.18                0.1       14880.0   267.8400
# 3         0.97                0.1       14880.0  1443.3600
# 4         0.83                0.6       19621.2  9771.3576
# 5         0.09                0.2       19621.2   353.1816
# 6         0.24                0.1       19621.2   470.9088
# 7         0.71                0.1       19621.2  1393.1052

# %% [markdown]
# ### Converte operações SQL presentes nas especificações de requisitos funcionais para a linguagem Python

# %% [markdown]
# #### _RF01 - Visualizar e extrair resultado da RVV de supervisores e vendedores_

# %%
df_RF01 = pd.read_sql_query("""
SELECT c.Matricula_do_Colaborador,
       c.Nome_do_Colaborador,
       c.Sexo,
       c.CPF,
       c.Data_Nascimento,
       c.Codigo_do_Departamento,
       d.Nome_do_Departamento,
       c.Codigo_do_Cargo,
       c2.Nome_do_Cargo,
       c.Salario,
       c.Status_do_Colaborador,
       c2.Base_de_Calculo,
       c3.Competencia,
       c3.Codigo_do_Indicador,
       i.Nome_do_Indicador,
       c3.Valor_da_Meta,
       c3.Valor_do_Resultado,
       c3.Atingimento,
       c3.Peso_do_Indicador,
       c3.Base_Calculo valor_base_calculo,
       c3.Comissao
FROM rvv.dbo.Colaborador AS c
    LEFT JOIN rvv.dbo.Departamento AS d
        ON d.Codigo_do_Departamento = c.Codigo_do_Departamento
    LEFT JOIN rvv.dbo.Cargo AS c2
        ON c2.Codigo_do_Cargo = c.Codigo_do_Cargo
    INNER JOIN rvv.dbo.Comissao AS c3
        ON c3.Matricula_do_Colaborador = c.Matricula_do_Colaborador
    LEFT JOIN rvv.dbo.Indicadores AS i
        ON i.Codigo_do_Indicador = c3.Codigo_do_Indicador
WHERE c2.nivel_hierarquia IN (3,4)
""", conectDB)

df_RF01.head(8)
# Out:
#    Matricula_do_Colaborador    Nome_do_Colaborador Sexo             CPF  \
# 0                   1000007  Maria Luiza Fernandes    F  309.851.267-95
# 1                   1000007  Maria Luiza Fernandes    F  309.851.267-95
# 2                   1000007  Maria Luiza Fernandes    F  309.851.267-95
# 3                   1000007  Maria Luiza Fernandes    F  309.851.267-95
# 4                   1000008          Murilo da Paz    M  321.705.694-99
# 5                   1000008          Murilo da Paz    M  321.705.694-99
# 6                   1000008          Murilo da Paz    M  321.705.694-99
# 7                   1000008          Murilo da Paz    M  321.705.694-99
#
#   Data_Nascimento  Codigo_do_Departamento Nome_do_Departamento  \
# 0      2001-01-19                    1002          Regional SP
# 1      2001-01-19                    1002          Regional SP
# 2      2001-01-19                    1002          Regional SP
# 3      2001-01-19                    1002          Regional SP
# 4      1985-05-15                    1002          Regional SP
# 5      1985-05-15                    1002          Regional SP
# 6      1985-05-15                    1002          Regional SP
# 7      1985-05-15                    1002          Regional SP
#
#    Codigo_do_Cargo       Nome_do_Cargo  Salario  ...  Base_de_Calculo  \
# 0             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 1             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 2             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 3             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 4             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 5             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 6             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 7             1003  Vendedor Comercial   4000.0  ...      Faturamento
#
#   Competencia Codigo_do_Indicador    Nome_do_Indicador Valor_da_Meta  \
# 0  2023-01-01                   5          Faturamento       80000.0
# 1  2023-01-01                   6  Qtde Itens Vendidos          20.0
# 2  2023-01-01                   7     Itens por Pedido           2.0
# 3  2023-01-01                   8            Devolucao        2400.0
# 4  2023-01-01                   5          Faturamento       78800.0
# 5  2023-01-01                   6  Qtde Itens Vendidos          26.0
# 6  2023-01-01                   7     Itens por Pedido           2.0
# 7  2023-01-01                   8            Devolucao        2364.0
#
#    Valor_do_Resultado  Atingimento  Peso_do_Indicador  valor_base_calculo  \
# 0            49600.00         0.62                0.6             14880.0
# 1                2.40         0.12                0.2             14880.0
# 2                0.36         0.18                0.1             14880.0
# 3             2328.00         0.97                0.1             14880.0
# 4            65404.00         0.83                0.6             19621.2
# 5                2.34         0.09                0.2             19621.2
# 6                0.48         0.24                0.1             19621.2
# 7             1678.44         0.71                0.1             19621.2
#
#     Comissao
# 0  5535.3600
# 1   357.1200
# 2   267.8400
# 3  1443.3600
# 4  9771.3576
# 5   353.1816
# 6   470.9088
# 7  1393.1052
#
# [8 rows x 21 columns]

# %% [markdown]
# #### _RF02 - Inserir metas dos Supervisores | RF05 - Inserir metas dos Vendedores_

# %%
# Definir a classe da tabela

Base = declarative_base()

class Meta(Base):
    __tablename__ = 'Meta'
    id_meta = Column(Integer, primary_key=True)
    Matricula_do_Colaborador = Column(String)
    Codigo_do_Indicador = Column(String)
    Inicio_Vigencia = Column(Date)
    Valor_da_Meta = Column(Float)

# %%
# Informar os valores:
Matricula_do_Colaborador = '1000021'
Codigo_do_Indicador = '24'
Inicio_Vigencia = '2023-03-01'
Valor_da_Meta = '1700.00'

try:    
    # Cria uma sessão
    Session = sessionmaker(bind=conectDB)
    session = Session()
    
    # Cria um novo objeto para inserção
    new_row = Meta(Matricula_do_Colaborador=Matricula_do_Colaborador, Codigo_do_Indicador=Codigo_do_Indicador, Inicio_Vigencia=Inicio_Vigencia, Valor_da_Meta=Valor_da_Meta )
    
    # Adiciona o objeto à sessão
    session.add(new_row)

    # Confirma a operação
    session.commit()
    
    print('Cadastro finalizado com sucesso!!!')
    df = pd.read_sql_query("SELECT TOP 1 * FROM rvv.dbo.Meta ORDER BY id_meta DESC", conectDB)
    display(df)
    
except Exception as e:
    print('Erro de cadastro:', e)
    
finally:
    # Fechar a sessão
    session.close()
# Out:
# Cadastro finalizado com sucesso!!!
#    id_meta  Matricula_do_Colaborador  Codigo_do_Indicador Inicio_Vigencia  \
# 0       61                   1000021                   24      2023-03-01
#
#   Final_Vigencia  Valor_da_Meta
# 0           None         1700.0

# %% [markdown]
# #### _RF03 - Visualizar metas e resultado de vendas por região_

# %%
df_RF03 = pd.read_sql_query("""
WITH tab
AS (SELECT c.Matricula_do_Colaborador,
           c.Nome_do_Colaborador,
           c.Sexo,
           c.CPF,
           c.Data_Nascimento,
           c.Codigo_do_Departamento,
           d.Nome_do_Departamento,
           c.Codigo_do_Cargo,
           c2.Nome_do_Cargo,
           c.Salario,
           c.Status_do_Colaborador,
           c2.Base_de_Calculo,
           c3.Competencia,
           c3.Codigo_do_Indicador,
           i.Nome_do_Indicador,
           c3.Valor_da_Meta,
           c3.Valor_do_Resultado,
           c3.Atingimento,
           c3.Peso_do_Indicador,
           c3.Base_Calculo valor_base_calculo,
           c3.Comissao
    FROM rvv.dbo.Colaborador AS c
        LEFT JOIN rvv.dbo.Departamento AS d
            ON d.Codigo_do_Departamento = c.Codigo_do_Departamento
        LEFT JOIN rvv.dbo.Cargo AS c2
            ON c2.Codigo_do_Cargo = c.Codigo_do_Cargo
        INNER JOIN rvv.dbo.Comissao AS c3
            ON c3.Matricula_do_Colaborador = c.Matricula_do_Colaborador
        LEFT JOIN rvv.dbo.Indicadores AS i
            ON i.Codigo_do_Indicador = c3.Codigo_do_Indicador)
SELECT DISTINCT
       tab.Nome_do_Departamento,
       SUM(tab.Valor_da_Meta) AS Valor_da_Meta,
       SUM(tab.Valor_do_Resultado) AS Valor_do_Resultado
FROM tab
GROUP BY tab.Nome_do_Departamento;
""", conectDB)

df_RF03
# Out:
#   Nome_do_Departamento  Valor_da_Meta  Valor_do_Resultado
# 0          Regional MG      365407.32           155473.67
# 1          Regional RJ      385583.87           285022.39
# 2          Regional SP      402314.10           289625.44

# %% [markdown]
# #### _RF04 - Cadastrar e atualizar registros de funcionários |  RF14 - Cadastrar e atualizar registros de funcionários_

# %%
# Definir a classe da tabela

Base = declarative_base()

class Colaborador(Base):
    __tablename__ = 'Colaborador'
    Matricula_do_Colaborador = Column(Integer, primary_key=True)
    Nome_do_Colaborador = Column(String)
    Sexo = Column(String)
    CPF = Column(String)
    Data_Nascimento = Column(Date)
    Codigo_do_Departamento = Column(Integer)
    Codigo_do_Cargo = Column(Integer)
    Salario = Column(Float)
    Status_do_Colaborador = Column(Boolean)

# %% [markdown]
# ##### _Cadastro de Funcionário_

# %%
# Informar os valores:
Nome_do_Colaborador = 'Priscila Aparecida'
Sexo = 'F'
CPF = '060.517.835-61'
Data_Nascimento = '1989-10-24'
Codigo_do_Departamento = '1004'
Codigo_do_Cargo = '1003'
Salario = '4100'
Status_do_Colaborador = True

try:    
    # Cria uma sessão
    Session = sessionmaker(bind=conectDB)
    session = Session()
    
    # Cria um novo objeto para inserção
    new_row = Colaborador(
        Nome_do_Colaborador = Nome_do_Colaborador, 
        Sexo = Sexo, 
        CPF = CPF, 
        Data_Nascimento = Data_Nascimento, 
        Codigo_do_Departamento = Codigo_do_Departamento, 
        Codigo_do_Cargo = Codigo_do_Cargo, 
        Salario = Salario, 
        Status_do_Colaborador = Status_do_Colaborador)
    
    # Adiciona o objeto à sessão
    session.add(new_row)

    # Confirma a operação
    session.commit()
    
    print('Cadastro finalizado com sucesso!!!')
    df = pd.read_sql_query("SELECT TOP 1 * FROM rvv.dbo.Colaborador ORDER BY Matricula_do_Colaborador DESC", conectDB)
    display(df)
    
except Exception as e:
    print('Erro de Cadastro:', e)
    
finally:
    # Fechar a sessão
    session.close()
# Out:
# Cadastro finalizado com sucesso!!!
#    Matricula_do_Colaborador Nome_do_Colaborador Sexo             CPF  \
# 0                   1000022  Priscila Aparecida    F  060.517.835-61
#
#   Data_Nascimento  Codigo_do_Departamento  Codigo_do_Cargo  Salario  \
# 0      1989-10-24                    1004             1003   4100.0
#
#    Status_do_Colaborador
# 0                   True

# %% [markdown]
# ##### _Atualização de Cadastro de Funcionário_

# %%
# Informar os valores:
Matricula_do_Colaborador = '1000022'
Nome_do_Colaborador = 'Priscila Aparecida Barbosa'

try:
    # Criar uma sessão
    Session = sessionmaker(bind=conectDB)
    session = Session()

    # Realizar o UPDATE
    session.query(Colaborador).filter(Colaborador.Matricula_do_Colaborador == Matricula_do_Colaborador).update({Colaborador.Nome_do_Colaborador: Nome_do_Colaborador})

    # Confirmar a operação
    session.commit()

    # Fechar a sessão
    session.close()

    print('Atualização finalizada com sucesso!!!')    
    df = pd.read_sql_query(f'SELECT * FROM rvv.dbo.Colaborador WHERE Matricula_do_Colaborador = {Matricula_do_Colaborador}', conectDB)
    display(df)
    
except Exception as e:
    print('Erro de Atualização de Cadastro', e)
    
finally:
    #Fechar a sessão
    session.close()
# Out:
# Atualização finalizada com sucesso!!!
#    Matricula_do_Colaborador         Nome_do_Colaborador Sexo             CPF  \
# 0                   1000022  Priscila Aparecida Barbosa    F  060.517.835-61
#
#   Data_Nascimento  Codigo_do_Departamento  Codigo_do_Cargo  Salario  \
# 0      1989-10-24                    1004             1003   4100.0
#
#    Status_do_Colaborador
# 0                   True

# %% [markdown]
# #### _RF06 - Visualizar metas e resultado de vendas por vendedor_

# %%
df_RF06 = pd.read_sql_query(""" 
WITH tab
AS (SELECT c.Matricula_do_Colaborador,
           c.Nome_do_Colaborador,
           c.Sexo,
           c.CPF,
           c.Data_Nascimento,
           c.Codigo_do_Departamento,
           d.Nome_do_Departamento,
           c.Codigo_do_Cargo,
           c2.Nome_do_Cargo,
           c.Salario,
           c.Status_do_Colaborador,
           c2.Base_de_Calculo,
           c3.Competencia,
           c3.Codigo_do_Indicador,
           i.Nome_do_Indicador,
           c3.Valor_da_Meta,
           c3.Valor_do_Resultado,
           c3.Atingimento,
           c3.Peso_do_Indicador,
           c3.Base_Calculo valor_base_calculo,
           c3.Comissao
    FROM rvv.dbo.Colaborador AS c
        LEFT JOIN rvv.dbo.Departamento AS d
            ON d.Codigo_do_Departamento = c.Codigo_do_Departamento
        LEFT JOIN rvv.dbo.Cargo AS c2
            ON c2.Codigo_do_Cargo = c.Codigo_do_Cargo
        INNER JOIN rvv.dbo.Comissao AS c3
            ON c3.Matricula_do_Colaborador = c.Matricula_do_Colaborador
        LEFT JOIN rvv.dbo.Indicadores AS i
            ON i.Codigo_do_Indicador = c3.Codigo_do_Indicador)
SELECT DISTINCT
       tab.Nome_do_Colaborador,
       tab.Nome_do_Departamento,
       tab.Nome_do_Cargo,
       SUM(tab.Valor_da_Meta) AS Valor_da_Meta,
       SUM(tab.Valor_do_Resultado) AS Valor_do_Resultado
FROM tab
GROUP BY tab.Nome_do_Colaborador,
         tab.Nome_do_Departamento,
         tab.Nome_do_Cargo;
""",conectDB)

df_RF06.head(8)
# Out:
#    Nome_do_Colaborador Nome_do_Departamento       Nome_do_Cargo  \
# 0     Ana Sophia Nunes          Regional MG  Vendedor Comercial
# 1     Erick Cavalcanti          Regional SP  Vendedor Comercial
# 2      Everton Augusto          Regional RJ  Vendedor Comercial
# 3    Fernanda Silveira          Regional RJ  Vendedor Comercial
# 4  Joao Felipe Barbosa          Regional MG  Vendedor Comercial
# 5    Joao Pedro Castro          Regional SP  Vendedor Comercial
# 6         Laura Moraes          Regional SP  Vendedor Comercial
# 7  Luiz Otávio Peixoto          Regional MG  Vendedor Comercial
#
#    Valor_da_Meta  Valor_do_Resultado
# 0       65492.86            13790.53
# 1       92727.00            75240.82
# 2       58249.87            19884.62
# 3       98520.75            92654.50
# 4       57320.75            41695.66
# 5       78668.50            46107.16
# 6       67304.60            49261.44
# 7       71670.86             7332.45

# %% [markdown]
# #### _RF07 - Realizar cálculo da RVV Final_

# %%
# Informar os valores:
competencia = '2023-01-01'

# Criar uma sessão
Session = sessionmaker(bind=conectDB)
session = Session()

# Executar a stored procedure
procedure_name = f"rvv.dbo.spr_calculo_rvv @competencia = '{competencia}', @matricula = 0"

try:
    session.execute(f"EXEC {procedure_name}")
    session.commit()

    print('Stored procedure executada com sucesso!')
    df = pd.read_sql_query("""
        SELECT c.Matricula_do_Colaborador,
               c.Nome_do_Colaborador,
               c.Sexo,
               c.CPF,
               c.Data_Nascimento,
               c.Codigo_do_Departamento,
               d.Nome_do_Departamento,
               c.Codigo_do_Cargo,
               c2.Nome_do_Cargo,
               c.Salario,
               c.Status_do_Colaborador,
               c2.Base_de_Calculo,
               c3.Competencia,
               c3.Codigo_do_Indicador,
               i.Nome_do_Indicador,
               c3.Valor_da_Meta,
               c3.Valor_do_Resultado,
               c3.Atingimento,
               c3.Peso_do_Indicador,
               c3.Base_Calculo valor_base_calculo,
               c3.Comissao
        FROM rvv.dbo.Colaborador AS c
            LEFT JOIN rvv.dbo.Departamento AS d
                ON d.Codigo_do_Departamento = c.Codigo_do_Departamento
            LEFT JOIN rvv.dbo.Cargo AS c2
                ON c2.Codigo_do_Cargo = c.Codigo_do_Cargo
            INNER JOIN rvv.dbo.Comissao AS c3
                ON c3.Matricula_do_Colaborador = c.Matricula_do_Colaborador
            LEFT JOIN rvv.dbo.Indicadores AS i
                ON i.Codigo_do_Indicador = c3.Codigo_do_Indicador
        WHERE c2.nivel_hierarquia IN (3,4)
        """, conectDB)
    display(df)
    
except Exception as e:
    print('Erro ao executar a stored procedure:', e)

# Fechar a sessão
session.close()
# Out:
# Stored procedure executada com sucesso!
#     Matricula_do_Colaborador    Nome_do_Colaborador Sexo             CPF  \
# 0                    1000007  Maria Luiza Fernandes    F  309.851.267-95
# 1                    1000007  Maria Luiza Fernandes    F  309.851.267-95
# 2                    1000007  Maria Luiza Fernandes    F  309.851.267-95
# 3                    1000007  Maria Luiza Fernandes    F  309.851.267-95
# 4                    1000008          Murilo da Paz    M  321.705.694-99
# 5                    1000008          Murilo da Paz    M  321.705.694-99
# 6                    1000008          Murilo da Paz    M  321.705.694-99
# 7                    1000008          Murilo da Paz    M  321.705.694-99
# 8                    1000009           Laura Moraes    F  529.087.143-88
# 9                    1000009           Laura Moraes    F  529.087.143-88
# 10                   1000009           Laura Moraes    F  529.087.143-88
# 11                   1000009           Laura Moraes    F  529.087.143-88
# 12                   1000010       Erick Cavalcanti    M  820.963.417-87
# 13                   1000010       Erick Cavalcanti    M  820.963.417-87
# 14                   1000010       Erick Cavalcanti    M  820.963.417-87
# 15                   1000010       Erick Cavalcanti    M  820.963.417-87
# 16                   1000011      Joao Pedro Castro    M  754.018.329-23
# 17                   1000011      Joao Pedro Castro    M  754.018.329-23
# 18                   1000011      Joao Pedro Castro    M  754.018.329-23
# 19                   1000011      Joao Pedro Castro    M  754.018.329-23
# 20                   1000012       Ana Sophia Nunes    F  617.025.893-40
# 21                   1000012       Ana Sophia Nunes    F  617.025.893-40
# 22                   1000012       Ana Sophia Nunes    F  617.025.893-40
# 23                   1000012       Ana Sophia Nunes    F  617.025.893-40
# 24                   1000013     Maria Alice Farias    F  675.192.038-59
# 25                   1000013     Maria Alice Farias    F  675.192.038-59
# 26                   1000013     Maria Alice Farias    F  675.192.038-59
# 27                   1000013     Maria Alice Farias    F  675.192.038-59
# 28                   1000014           Yasmin Sales    F  236.108.974-22
# 29                   1000014           Yasmin Sales    F  236.108.974-22
# 30                   1000014           Yasmin Sales    F  236.108.974-22
# 31                   1000014           Yasmin Sales    F  236.108.974-22
# 32                   1000015    Joao Felipe Barbosa    M  564.102.839-89
# 33                   1000015    Joao Felipe Barbosa    M  564.102.839-89
# 34                   1000015    Joao Felipe Barbosa    M  564.102.839-89
# 35                   1000015    Joao Felipe Barbosa    M  564.102.839-89
# 36                   1000016    Luiz Otávio Peixoto    M  851.374.692-46
# 37                   1000016    Luiz Otávio Peixoto    M  851.374.692-46
# 38                   1000016    Luiz Otávio Peixoto    M  851.374.692-46
# 39                   1000016    Luiz Otávio Peixoto    M  851.374.692-46
# 40                   1000017         Nathan da Mata    M  748.059.321-04
# 41                   1000017         Nathan da Mata    M  748.059.321-04
# 42                   1000017         Nathan da Mata    M  748.059.321-04
# 43                   1000017         Nathan da Mata    M  748.059.321-04
# 44                   1000018        Melissa Correia    F  346.071.925-70
# 45                   1000018        Melissa Correia    F  346.071.925-70
# 46                   1000018        Melissa Correia    F  346.071.925-70
# 47                   1000018        Melissa Correia    F  346.071.925-70
# 48                   1000019      Fernanda Silveira    F  421.938.576-28
# 49                   1000019      Fernanda Silveira    F  421.938.576-28
# 50                   1000019      Fernanda Silveira    F  421.938.576-28
# 51                   1000019      Fernanda Silveira    F  421.938.576-28
# 52                   1000020           Samuel Rocha    M  430.678.192-50
# 53                   1000020           Samuel Rocha    M  430.678.192-50
# 54                   1000020           Samuel Rocha    M  430.678.192-50
# 55                   1000020           Samuel Rocha    M  430.678.192-50
# 56                   1000021        Everton Augusto    M  159.753.456-55
# 57                   1000021        Everton Augusto    M  159.753.456-55
# 58                   1000021        Everton Augusto    M  159.753.456-55
# 59                   1000021        Everton Augusto    M  159.753.456-55
#
#    Data_Nascimento  Codigo_do_Departamento Nome_do_Departamento  \
# 0       2001-01-19                    1002          Regional SP
# 1       2001-01-19                    1002          Regional SP
# 2       2001-01-19                    1002          Regional SP
# 3       2001-01-19                    1002          Regional SP
# 4       1985-05-15                    1002          Regional SP
# 5       1985-05-15                    1002          Regional SP
# 6       1985-05-15                    1002          Regional SP
# 7       1985-05-15                    1002          Regional SP
# 8       2004-03-16                    1002          Regional SP
# 9       2004-03-16                    1002          Regional SP
# 10      2004-03-16                    1002          Regional SP
# 11      2004-03-16                    1002          Regional SP
# 12      1979-03-28                    1002          Regional SP
# 13      1979-03-28                    1002          Regional SP
# 14      1979-03-28                    1002          Regional SP
# 15      1979-03-28                    1002          Regional SP
# 16      1999-11-05                    1002          Regional SP
# 17      1999-11-05                    1002          Regional SP
# 18      1999-11-05                    1002          Regional SP
# 19      1999-11-05                    1002          Regional SP
# 20      2000-08-03                    1003          Regional MG
# 21      2000-08-03                    1003          Regional MG
# 22      2000-08-03                    1003          Regional MG
# 23      2000-08-03                    1003          Regional MG
# 24      1985-11-15                    1003          Regional MG
# 25      1985-11-15                    1003          Regional MG
# 26      1985-11-15                    1003          Regional MG
# 27      1985-11-15                    1003          Regional MG
# 28      1977-09-10                    1003          Regional MG
# 29      1977-09-10                    1003          Regional MG
# 30      1977-09-10                    1003          Regional MG
# 31      1977-09-10                    1003          Regional MG
# 32      1998-07-12                    1003          Regional MG
# 33      1998-07-12                    1003          Regional MG
# 34      1998-07-12                    1003          Regional MG
# 35      1998-07-12                    1003          Regional MG
# 36      1985-01-25                    1003          Regional MG
# 37      1985-01-25                    1003          Regional MG
# 38      1985-01-25                    1003          Regional MG
# 39      1985-01-25                    1003          Regional MG
# 40      2000-03-08                    1004          Regional RJ
# 41      2000-03-08                    1004          Regional RJ
# 42      2000-03-08                    1004          Regional RJ
# 43      2000-03-08                    1004          Regional RJ
# 44      1972-01-09                    1004          Regional RJ
# 45      1972-01-09                    1004          Regional RJ
# 46      1972-01-09                    1004          Regional RJ
# 47      1972-01-09                    1004          Regional RJ
# 48      1998-02-17                    1004          Regional RJ
# 49      1998-02-17                    1004          Regional RJ
# 50      1998-02-17                    1004          Regional RJ
# 51      1998-02-17                    1004          Regional RJ
# 52      2001-05-21                    1004          Regional RJ
# 53      2001-05-21                    1004          Regional RJ
# 54      2001-05-21                    1004          Regional RJ
# 55      2001-05-21                    1004          Regional RJ
# 56      2000-02-05                    1004          Regional RJ
# 57      2000-02-05                    1004          Regional RJ
# 58      2000-02-05                    1004          Regional RJ
# 59      2000-02-05                    1004          Regional RJ
#
#     Codigo_do_Cargo       Nome_do_Cargo  Salario  ...  Base_de_Calculo  \
# 0              1003  Vendedor Comercial   4000.0  ...      Faturamento
# 1              1003  Vendedor Comercial   4000.0  ...      Faturamento
# 2              1003  Vendedor Comercial   4000.0  ...      Faturamento
# 3              1003  Vendedor Comercial   4000.0  ...      Faturamento
# 4              1003  Vendedor Comercial   4000.0  ...      Faturamento
# 5              1003  Vendedor Comercial   4000.0  ...      Faturamento
# 6              1003  Vendedor Comercial   4000.0  ...      Faturamento
# 7              1003  Vendedor Comercial   4000.0  ...      Faturamento
# 8              1003  Vendedor Comercial   4000.0  ...      Faturamento
# 9              1003  Vendedor Comercial   4000.0  ...      Faturamento
# 10             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 11             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 12             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 13             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 14             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 15             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 16             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 17             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 18             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 19             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 20             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 21             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 22             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 23             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 24             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 25             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 26             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 27             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 28             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 29             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 30             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 31             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 32             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 33             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 34             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 35             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 36             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 37             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 38             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 39             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 40             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 41             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 42             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 43             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 44             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 45             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 46             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 47             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 48             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 49             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 50             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 51             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 52             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 53             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 54             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 55             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 56             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 57             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 58             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 59             1003  Vendedor Comercial   4000.0  ...      Faturamento
#
#    Competencia Codigo_do_Indicador    Nome_do_Indicador Valor_da_Meta  \
# 0   2023-01-01                   5          Faturamento      80000.00
# 1   2023-01-01                   6  Qtde Itens Vendidos         20.00
# 2   2023-01-01                   7     Itens por Pedido          2.00
# 3   2023-01-01                   8            Devolucao       2400.00
# 4   2023-01-01                   5          Faturamento      78800.00
# 5   2023-01-01                   6  Qtde Itens Vendidos         26.00
# 6   2023-01-01                   7     Itens por Pedido          2.00
# 7   2023-01-01                   8            Devolucao       2364.00
# 8   2023-01-01                   5          Faturamento      65320.00
# 9   2023-01-01                   6  Qtde Itens Vendidos         23.00
# 10  2023-01-01                   7     Itens por Pedido          2.00
# 11  2023-01-01                   8            Devolucao       1959.60
# 12  2023-01-01                   5          Faturamento      90000.00
# 13  2023-01-01                   6  Qtde Itens Vendidos         25.00
# 14  2023-01-01                   7     Itens por Pedido          2.00
# 15  2023-01-01                   8            Devolucao       2700.00
# 16  2023-01-01                   5          Faturamento      76350.00
# 17  2023-01-01                   6  Qtde Itens Vendidos         26.00
# 18  2023-01-01                   7     Itens por Pedido          2.00
# 19  2023-01-01                   8            Devolucao       2290.50
# 20  2023-01-01                  13          Faturamento      63562.00
# 21  2023-01-01                  14  Qtde Itens Vendidos         22.00
# 22  2023-01-01                  15     Itens por Pedido          2.00
# 23  2023-01-01                  16            Devolucao       1906.86
# 24  2023-01-01                  13          Faturamento      75642.00
# 25  2023-01-01                  14  Qtde Itens Vendidos         24.00
# 26  2023-01-01                  15     Itens por Pedido          2.00
# 27  2023-01-01                  16            Devolucao       2269.26
# 28  2023-01-01                  13          Faturamento      90253.00
# 29  2023-01-01                  14  Qtde Itens Vendidos         23.00
# 30  2023-01-01                  15     Itens por Pedido          2.00
# 31  2023-01-01                  16            Devolucao       2707.59
# 32  2023-01-01                  13          Faturamento      55625.00
# 33  2023-01-01                  14  Qtde Itens Vendidos         25.00
# 34  2023-01-01                  15     Itens por Pedido          2.00
# 35  2023-01-01                  16            Devolucao       1668.75
# 36  2023-01-01                  13          Faturamento      69562.00
# 37  2023-01-01                  14  Qtde Itens Vendidos         20.00
# 38  2023-01-01                  15     Itens por Pedido          2.00
# 39  2023-01-01                  16            Devolucao       2086.86
# 40  2023-01-01                  21          Faturamento      75695.00
# 41  2023-01-01                  22  Qtde Itens Vendidos         20.00
# 42  2023-01-01                  23     Itens por Pedido          2.00
# 43  2023-01-01                  24            Devolucao       2270.85
# 44  2023-01-01                  21          Faturamento      80985.00
# 45  2023-01-01                  22  Qtde Itens Vendidos         26.00
# 46  2023-01-01                  23     Itens por Pedido          2.00
# 47  2023-01-01                  24            Devolucao       2429.55
# 48  2023-01-01                  21          Faturamento      95625.00
# 49  2023-01-01                  22  Qtde Itens Vendidos         25.00
# 50  2023-01-01                  23     Itens por Pedido          2.00
# 51  2023-01-01                  24            Devolucao       2868.75
# 52  2023-01-01                  21          Faturamento      65395.00
# 53  2023-01-01                  22  Qtde Itens Vendidos         24.00
# 54  2023-01-01                  23     Itens por Pedido          2.00
# 55  2023-01-01                  24            Devolucao       1961.85
# 56  2023-01-01                  21          Faturamento      56529.00
# 57  2023-01-01                  22  Qtde Itens Vendidos         23.00
# 58  2023-01-01                  23     Itens por Pedido          2.00
# 59  2023-01-01                  24            Devolucao       1695.87
#
#     Valor_do_Resultado  Atingimento  Peso_do_Indicador  valor_base_calculo  \
# 0             49600.00     0.620000                0.6           14880.000
# 1                 2.40     0.120000                0.2           14880.000
# 2                 0.36     0.180000                0.1           14880.000
# 3              2328.00     0.970000                0.1           14880.000
# 4             65404.00     0.830000                0.6           19621.200
# 5                 2.34     0.090000                0.2           19621.200
# 6                 0.48     0.240000                0.1           19621.200
# 7              1678.44     0.710000                0.1           19621.200
# 8             47683.60     0.730000                0.6           14305.080
# 9                 9.66     0.420000                0.2           14305.080
# 10                0.50     0.250000                0.1           14305.080
# 11             1567.68     0.800000                0.1           14305.080
# 12            72900.00     0.810000                0.6           21870.000
# 13               18.00     0.720000                0.2           21870.000
# 14                0.82     0.410000                0.1           21870.000
# 15             2322.00     0.860000                0.1           21870.000
# 16            45810.00     0.600000                0.6           13743.000
# 17               21.32     0.820000                0.2           13743.000
# 18                0.98     0.490000                0.1           13743.000
# 19              274.86     0.120000                0.1           13743.000
# 20            12076.78     0.190000                0.6            3623.034
# 21               16.06     0.730000                0.2            3623.034
# 22                0.58     0.290000                0.1            3623.034
# 23             1697.11     0.890002                0.1            3623.034
# 24            71103.48     0.940000                0.6           21331.044
# 25               12.48     0.520000                0.2           21331.044
# 26                1.12     0.560000                0.1           21331.044
# 27              136.16     0.060001                0.1           21331.044
# 28            20758.19     0.230000                0.6            6227.457
# 29               19.09     0.830000                0.2            6227.457
# 30                1.76     0.880000                0.1            6227.457
# 31              622.75     0.230001                0.1            6227.457
# 32            40606.25     0.730000                0.6           12181.875
# 33                4.00     0.160000                0.2           12181.875
# 34                0.72     0.360000                0.1           12181.875
# 35             1084.69     0.650001                0.1           12181.875
# 36             6956.20     0.100000                0.6            2086.860
# 37               20.00     1.000000                0.2            2086.860
# 38                1.48     0.740000                0.1            2086.860
# 39              354.77     0.170001                0.1            2086.860
# 40            42389.20     0.560000                0.6           12716.760
# 41               19.20     0.960000                0.2           12716.760
# 42                0.46     0.230000                0.1           12716.760
# 43              999.17     0.439998                0.1           12716.760
# 44            69647.10     0.860000                0.6           20894.130
# 45                7.02     0.270000                0.2           20894.130
# 46                0.68     0.340000                0.1           20894.130
# 47             2356.66     0.969998                0.1           20894.130
# 48            91800.00     0.960000                0.6           27540.000
# 49               21.00     0.840000                0.2           27540.000
# 50                1.56     0.780000                0.1           27540.000
# 51              831.94     0.290000                0.1           27540.000
# 52            56239.70     0.860000                0.6           16871.910
# 53               18.48     0.770000                0.2           16871.910
# 54                1.24     0.620000                0.1           16871.910
# 55              804.36     0.410000                0.1           16871.910
# 56            19219.86     0.340000                0.6            5765.958
# 57                2.53     0.110000                0.2            5765.958
# 58                0.84     0.420000                0.1            5765.958
# 59              661.39     0.390000                0.1            5765.958
#
#         Comissao
# 0    5535.360000
# 1     357.120000
# 2     267.840000
# 3    1443.360000
# 4    9771.357600
# 5     353.181600
# 6     470.908800
# 7    1393.105200
# 8    6265.625040
# 9    1201.626720
# 10    357.627000
# 11   1144.406400
# 12  10628.820000
# 13   3149.280000
# 14    896.670000
# 15   1880.820000
# 16   4947.480000
# 17   2253.852000
# 18    673.407000
# 19    164.916000
# 20    413.025876
# 21    528.962964
# 22    105.067986
# 23    322.450026
# 24  12030.708816
# 25   2218.428576
# 26   1194.538464
# 27    127.986264
# 28    859.389066
# 29   1033.757862
# 30    548.016216
# 31    143.231511
# 32   5335.661250
# 33    389.820000
# 34    438.547500
# 35    791.821875
# 36    125.211600
# 37    417.372000
# 38    154.427640
# 39     35.476620
# 40   4272.831360
# 41   2441.617920
# 42    292.485480
# 43    559.537440
# 44  10781.371080
# 45   1128.283020
# 46    710.400420
# 47   2026.730610
# 48  15863.040000
# 49   4626.720000
# 50   2148.120000
# 51    798.660000
# 52   8705.905560
# 53   2598.274140
# 54   1046.058420
# 55    691.748310
# 56   1176.255432
# 57    126.851076
# 58    242.170236
# 59    224.872362
#
# [60 rows x 21 columns]

# %% [markdown]
# #### _RF08 - Visualizar e extrair cálculo da RVV_

# %%
df_RF08 = pd.read_sql_query("""
SELECT c.Matricula_do_Colaborador,
       c.Nome_do_Colaborador,
       c.Sexo,
       c.CPF,
       c.Data_Nascimento,
       c.Codigo_do_Departamento,
       d.Nome_do_Departamento,
       c.Codigo_do_Cargo,
       c2.Nome_do_Cargo,
       c.Salario,
       c.Status_do_Colaborador,
       c2.Base_de_Calculo,
       c3.Competencia,
       c3.Codigo_do_Indicador,
       i.Nome_do_Indicador,
       c3.Valor_da_Meta,
       c3.Valor_do_Resultado,
       c3.Atingimento,
       c3.Peso_do_Indicador,
       c3.Base_Calculo valor_base_calculo,
       c3.Comissao
FROM rvv.dbo.Colaborador AS c
    LEFT JOIN rvv.dbo.Departamento AS d
        ON d.Codigo_do_Departamento = c.Codigo_do_Departamento
    LEFT JOIN rvv.dbo.Cargo AS c2
        ON c2.Codigo_do_Cargo = c.Codigo_do_Cargo
    INNER JOIN rvv.dbo.Comissao AS c3
        ON c3.Matricula_do_Colaborador = c.Matricula_do_Colaborador
    LEFT JOIN rvv.dbo.Indicadores AS i
        ON i.Codigo_do_Indicador = c3.Codigo_do_Indicador
""", conectDB)

df_RF08.head(8)
# Out:
#    Matricula_do_Colaborador    Nome_do_Colaborador Sexo             CPF  \
# 0                   1000007  Maria Luiza Fernandes    F  309.851.267-95
# 1                   1000007  Maria Luiza Fernandes    F  309.851.267-95
# 2                   1000007  Maria Luiza Fernandes    F  309.851.267-95
# 3                   1000007  Maria Luiza Fernandes    F  309.851.267-95
# 4                   1000008          Murilo da Paz    M  321.705.694-99
# 5                   1000008          Murilo da Paz    M  321.705.694-99
# 6                   1000008          Murilo da Paz    M  321.705.694-99
# 7                   1000008          Murilo da Paz    M  321.705.694-99
#
#   Data_Nascimento  Codigo_do_Departamento Nome_do_Departamento  \
# 0      2001-01-19                    1002          Regional SP
# 1      2001-01-19                    1002          Regional SP
# 2      2001-01-19                    1002          Regional SP
# 3      2001-01-19                    1002          Regional SP
# 4      1985-05-15                    1002          Regional SP
# 5      1985-05-15                    1002          Regional SP
# 6      1985-05-15                    1002          Regional SP
# 7      1985-05-15                    1002          Regional SP
#
#    Codigo_do_Cargo       Nome_do_Cargo  Salario  ...  Base_de_Calculo  \
# 0             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 1             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 2             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 3             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 4             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 5             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 6             1003  Vendedor Comercial   4000.0  ...      Faturamento
# 7             1003  Vendedor Comercial   4000.0  ...      Faturamento
#
#   Competencia Codigo_do_Indicador    Nome_do_Indicador Valor_da_Meta  \
# 0  2023-01-01                   5          Faturamento       80000.0
# 1  2023-01-01                   6  Qtde Itens Vendidos          20.0
# 2  2023-01-01                   7     Itens por Pedido           2.0
# 3  2023-01-01                   8            Devolucao        2400.0
# 4  2023-01-01                   5          Faturamento       78800.0
# 5  2023-01-01                   6  Qtde Itens Vendidos          26.0
# 6  2023-01-01                   7     Itens por Pedido           2.0
# 7  2023-01-01                   8            Devolucao        2364.0
#
#    Valor_do_Resultado  Atingimento  Peso_do_Indicador  valor_base_calculo  \
# 0            49600.00         0.62                0.6             14880.0
# 1                2.40         0.12                0.2             14880.0
# 2                0.36         0.18                0.1             14880.0
# 3             2328.00         0.97                0.1             14880.0
# 4            65404.00         0.83                0.6             19621.2
# 5                2.34         0.09                0.2             19621.2
# 6                0.48         0.24                0.1             19621.2
# 7             1678.44         0.71                0.1             19621.2
#
#     Comissao
# 0  5535.3600
# 1   357.1200
# 2   267.8400
# 3  1443.3600
# 4  9771.3576
# 5   353.1816
# 6   470.9088
# 7  1393.1052
#
# [8 rows x 21 columns]

# %% [markdown]
# #### _RF09 - Visualizar e extrair cálculo da RVV por região_

# %%
df_RF09 = pd.read_sql_query(""" 
WITH tab
AS (SELECT c.Matricula_do_Colaborador,
           c.Nome_do_Colaborador,
           c.Sexo,
           c.CPF,
           c.Data_Nascimento,
           c.Codigo_do_Departamento,
           d.Nome_do_Departamento,
           c.Codigo_do_Cargo,
           c2.Nome_do_Cargo,
           c.Salario,
           c.Status_do_Colaborador,
           c2.Base_de_Calculo,
           c3.Competencia,
           c3.Codigo_do_Indicador,
           i.Nome_do_Indicador,
           c3.Valor_da_Meta,
           c3.Valor_do_Resultado,
           c3.Atingimento,
           c3.Peso_do_Indicador,
           c3.Base_Calculo valor_base_calculo,
           c3.Comissao
    FROM rvv.dbo.Colaborador AS c
        LEFT JOIN rvv.dbo.Departamento AS d
            ON d.Codigo_do_Departamento = c.Codigo_do_Departamento
        LEFT JOIN rvv.dbo.Cargo AS c2
            ON c2.Codigo_do_Cargo = c.Codigo_do_Cargo
        INNER JOIN rvv.dbo.Comissao AS c3
            ON c3.Matricula_do_Colaborador = c.Matricula_do_Colaborador
        LEFT JOIN rvv.dbo.Indicadores AS i
            ON i.Codigo_do_Indicador = c3.Codigo_do_Indicador)
SELECT DISTINCT
       tab.Nome_do_Departamento,
       SUM(tab.Comissao) AS Valor_da_Comissao
FROM tab
GROUP BY tab.Nome_do_Departamento
""",conectDB)

df_RF09
# Out:
#   Nome_do_Departamento  Valor_da_Comissao
# 0          Regional MG       27213.902112
# 1          Regional RJ       60461.932866
# 2          Regional SP       53156.763360

# %% [markdown]
# #### _RF10 - Criar e atualizar cadastro de departamentos_

# %%
# Definir a classe da tabela

Base = declarative_base()

class Departamento(Base):
    __tablename__ = 'Departamento'
    Codigo_do_Departamento = Column(Integer, primary_key=True)
    Nome_do_Departamento = Column(String)
    Status_do_Departamento = Column(Boolean)

# %% [markdown]
# ####  _Cadastro de Departamento_

# %%
# Informar os valores:
Nome_do_Departamento = 'Departamento Teste'
Status_do_Departamento = True

try:
    # Cria uma sessão
    Session = sessionmaker(bind=conectDB)
    session = Session()
    
    #Cria um novo objeto para inserção
    new_row = Departamento(
        Nome_do_Departamento = Nome_do_Departamento,
        Status_do_Departamento = Status_do_Departamento     
    )
    
    #Adiciona o objeto à sessão
    session.add(new_row)
    
    #Confirma a operação
    session.commit()
    
    print('Cadastro finalizado com sucesso!!!')
    df = pd.read_sql_query("SELECT TOP 1 * FROM rvv.dbo.Departamento ORDER BY Codigo_do_Departamento DESC", conectDB)
    display(df)
    
except Exception as e:
    print('Erro de cadastro:', e)
    
finally:
    #Fechar a sessão
    session.close()
# Out:
# Cadastro finalizado com sucesso!!!
#    Codigo_do_Departamento Nome_do_Departamento  Status_do_Departamento
# 0                    1006   Departamento Teste                    True

# %% [markdown]
# #### _Atualização de Cadastro de Departamento_

# %%
# Informar os valores:
Codigo_do_Departamento = '1006'
Nome_do_Departamento = 'Departamento A'

try:
     # Criar uma sessão
    Session = sessionmaker(bind=conectDB)
    session = Session()
    
    # Realizar o UPDATE
    session.query(Departamento).filter(Departamento.Codigo_do_Departamento == Codigo_do_Departamento).update({Departamento.Nome_do_Departamento: Nome_do_Departamento})  
    
    # Confirmar a operação
    session.commit()

    # Fechar a sessão
    session.close() 
    
    print('Atualização finalizada com sucesso!!!')
    df = pd.read_sql_query(f'SELECT TOP 1 * FROM rvv.dbo.Departamento WHERE Codigo_do_Departamento = {Codigo_do_Departamento}', conectDB)
    display(df)
    
except Exception as e:
    print('Erro de cadastro', e)
    
finally:
    #Fechar a sessão
    session.close()
# Out:
# Atualização finalizada com sucesso!!!
#    Codigo_do_Departamento Nome_do_Departamento  Status_do_Departamento
# 0                    1006       Departamento A                    True

# %% [markdown]
# #### RF11 - Criar e atualizar cadastro de cargos

# %%
# Definir a classe da tabela

Base = declarative_base()

class Cargo(Base):
    __tablename__ = 'Cargo'
    Codigo_do_Cargo = Column(Integer, primary_key=True)
    Nome_do_Cargo = Column(String)
    Status_do_Cargo = Column(Boolean)
    nivel_hierarquia = Column(Integer)
    Base_de_Calculo = Column(String)

# %% [markdown]
# ####  _Cadastro de Cargo_

# %%
# Informar os valores:
Nome_do_Cargo = 'Cargo Teste'
Status_do_Cargo = True
nivel_hierarquia = '4'
Base_de_Calculo = 'Faturamento'

try:
    # Cria uma sessão
    Session = sessionmaker(bind=conectDB)
    session = Session()
    
    #Cria um novo objeto para inserção
    new_row = Cargo(
        Nome_do_Cargo = Nome_do_Cargo,
        Status_do_Cargo = Status_do_Cargo,
        nivel_hierarquia = nivel_hierarquia,
        Base_de_Calculo = Base_de_Calculo        
    )
    
    #Adiciona o objeto à sessão
    session.add(new_row)
    
    #Confirma a operação
    session.commit()
    
    print('Cadastro finalizado com sucesso!!!')
    df = pd.read_sql_query("SELECT TOP 1 * FROM rvv.dbo.Cargo ORDER BY Codigo_do_Cargo DESC", conectDB)
    display(df)
    
except Exception as e:
    print('Erro de cadastro:', e)
    
finally:
    #Fechar a sessão
    session.close()
# Out:
# Cadastro finalizado com sucesso!!!
#    Codigo_do_Cargo Nome_do_Cargo  Status_do_Cargo  nivel_hierarquia  \
# 0             1005   Cargo Teste             True                 4
#
#   Base_de_Calculo
# 0     Faturamento

# %% [markdown]
# ####  _Atualização de Cadastro de Cargo_

# %%
# Informar os valores:
Codigo_do_Cargo = '1005'
Nome_do_Cargo = 'Carga A'

try:
     # Criar uma sessão
    Session = sessionmaker(bind=conectDB)
    session = Session()
    
    # Realizar o UPDATE
    session.query(Cargo).filter(Cargo.Codigo_do_Cargo == Codigo_do_Cargo).update({Cargo.Nome_do_Cargo: Nome_do_Cargo})  
    
    # Confirmar a operação
    session.commit()

    # Fechar a sessão
    session.close() 
    
    print('Atualização finalizada com sucesso!!!')
    df = pd.read_sql_query(f'SELECT TOP 1 * FROM rvv.dbo.Cargo WHERE Codigo_do_Cargo = {Codigo_do_Cargo}', conectDB)
    display(df)
    
except Exception as e:
    print('Erro de cadastro', e)
    
finally:
    #Fechar a sessão
    session.close()
# Out:
# Atualização finalizada com sucesso!!!
#    Codigo_do_Cargo Nome_do_Cargo  Status_do_Cargo  nivel_hierarquia  \
# 0             1005       Carga A             True                 4
#
#   Base_de_Calculo
# 0     Faturamento

# %% [markdown]
# #### RF12 - Criar e atualizar cadastro de indicadores

# %%
# Definir a classe da tabela

Base = declarative_base()

class Indicadores(Base):
    __tablename__ = 'Indicadores'
    Codigo_do_Indicador = Column(Integer, primary_key=True)
    Nome_do_Indicador = Column(String)
    Codigo_do_Departamento = Column(Integer)
    Codigo_do_Cargo = Column(Integer)
    Peso_do_Indicador = Column(Float)
    Inicio_Vigencia = Column(Date)
    Final_Vigencia = Column(Date)

# %% [markdown]
# ####  _Cadastro de Indicadores_

# %%
# Informar os valores:
Nome_do_Indicador = 'Indicador Teste'
Codigo_do_Departamento = '1004'
Codigo_do_Cargo = '1003'
Peso_do_Indicador = '0.1'
Inicio_Vigencia = '2023-02-01'

try:
    # Cria uma sessão
    Session = sessionmaker(bind=conectDB)
    session = Session()
    
    #Cria um novo objeto para inserção
    new_row = Indicadores(
        Nome_do_Indicador = Nome_do_Indicador,
        Codigo_do_Departamento = Codigo_do_Departamento,
        Codigo_do_Cargo = Codigo_do_Cargo,
        Peso_do_Indicador = Peso_do_Indicador,
        Inicio_Vigencia = Inicio_Vigencia
    )
    
    #Adiciona o objeto à sessão
    session.add(new_row)
    
    #Confirma a operação
    session.commit()
    
    print('Cadastro finalizado com sucesso!!!')
    df = pd.read_sql_query("SELECT TOP 1 * FROM rvv.dbo.Indicadores ORDER BY Codigo_do_Indicador DESC", conectDB)
    display(df)
    
except Exception as e:
    print('Erro de cadastro:', e)
    
finally:
    #Fechar a sessão
    session.close()
# Out:
# Cadastro finalizado com sucesso!!!
#    Codigo_do_Indicador Nome_do_Indicador  Codigo_do_Departamento  \
# 0                   25   Indicador Teste                    1004
#
#    Codigo_do_Cargo  Peso_do_Indicador Inicio_Vigencia Final_Vigencia
# 0             1003                0.1      2023-02-01           None

# %% [markdown]
# ####  _Atualização de Cadastro de Indicadores_

# %%
# Informar os valores:
cod_indicador = '25'
nome_indicador_atualizacao = 'Indicador A'

try:
     # Criar uma sessão
    Session = sessionmaker(bind=conectDB)
    session = Session()
    
    # Realizar o UPDATE
    session.query(Indicadores).filter(Indicadores.Codigo_do_Indicador == cod_indicador).update({Indicadores.Nome_do_Indicador: nome_indicador_atualizacao})  
    
    # Confirmar a operação
    session.commit()

    # Fechar a sessão
    session.close() 
    
    print('Atualização finalizada com sucesso!!!')
    df = pd.read_sql_query(f'SELECT TOP 1 * FROM rvv.dbo.Indicadores WHERE Codigo_do_Indicador = {cod_indicador}', conectDB)
    display(df)
    
except Exception as e:
    print('Erro de cadastro', e)
    
finally:
    #Fechar a sessão
    session.close()
# Out:
# Atualização finalizada com sucesso!!!
#    Codigo_do_Indicador Nome_do_Indicador  Codigo_do_Departamento  \
# 0                   25       Indicador A                    1004
#
#    Codigo_do_Cargo  Peso_do_Indicador Inicio_Vigencia Final_Vigencia
# 0             1003                0.1      2023-02-01           None

# %% [markdown]
# #### RF13 - Lançar o resultado de vendas

# %%
# Definir a classe da tabela

Base = declarative_base()

class Resultado(Base):
    __tablename__ = 'Resultado'
    id_resultado = Column(Integer, primary_key=True)
    Matricula_do_Colaborador = Column(Integer)
    Codigo_do_Indicador = Column(Integer)
    Competencia = Column(Date)
    Valor_do_Resultado = Column(Float)

# %%
# Informar os valores:
matricula = '1000021'
cod_indicador = '24'
competencia = '2023-02-01'
valor_resultado = '565.85'


try:
    # Cria uma sessão
    Session = sessionmaker(bind=conectDB)
    session = Session()
    
    #Cria um novo objeto para inserção
    new_row = Resultado(
        Matricula_do_Colaborador = matricula,
        Codigo_do_Indicador = cod_indicador,
        Competencia = competencia,
        Valor_do_Resultado = valor_resultado
    )
    
    #Adiciona o objeto à sessão
    session.add(new_row)
    
    #Confirma a operação
    session.commit()
    
    print('Cadastro finalizado com sucesso!!!')
    df = pd.read_sql_query("SELECT TOP 1 * FROM rvv.dbo.Resultado ORDER BY id_resultado DESC", conectDB)
    display(df)
    
except Exception as e:
    print('Erro de cadastro:', e)
    
finally:
    #Fechar a sessão
    session.close()
# Out:
# Cadastro finalizado com sucesso!!!
#    id_resultado  Matricula_do_Colaborador  Codigo_do_Indicador Competencia  \
# 0            61                   1000021                   24  2023-02-01
#
#    Valor_do_Resultado
# 0              565.85

# %% [markdown]
# #### RF15 - Inserir metas dos Vendedores

# %%
# Definir a classe da tabela

Base = declarative_base()

class Meta(Base):
    __tablename__ = 'Meta'
    id_meta = Column(Integer, primary_key=True)
    Matricula_do_Colaborador = Column(Integer)
    Codigo_do_Indicador = Column(Integer)
    Inicio_Vigencia = Column(Date)
    Final_Vigencia = Column(Date)
    Valor_da_Meta = Column(Float)

# %%
# Informar os valores:
matricula = '1000021'
cod_indicador = '24'
inicio_vigencia = '2023-02-01'
valor_resultado = '400.85'


try:
    # Cria uma sessão
    Session = sessionmaker(bind=conectDB)
    session = Session()
    
    #Cria um novo objeto para inserção
    new_row = Meta(
        Matricula_do_Colaborador = matricula,
        Codigo_do_Indicador = cod_indicador,
        Inicio_Vigencia = competencia,
        Valor_da_Meta = valor_resultado
    )
    
    #Adiciona o objeto à sessão
    session.add(new_row)
    
    #Confirma a operação
    session.commit()
    
    print('Cadastro finalizado com sucesso!!!')
    df = pd.read_sql_query("SELECT TOP 1 * FROM rvv.dbo.Meta ORDER BY id_meta DESC", conectDB)
    display(df)
    
except Exception as e:
    print('Erro de cadastro:', e)
    
finally:
    #Fechar a sessão
    session.close()
# Out:
# Cadastro finalizado com sucesso!!!
#    id_meta  Matricula_do_Colaborador  Codigo_do_Indicador Inicio_Vigencia  \
# 0       62                   1000021                   24      2023-02-01
#
#   Final_Vigencia  Valor_da_Meta
# 0           None         400.85
